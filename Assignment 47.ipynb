# %%
Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?
Ans. import pandas as pd

# Load the dataset
flight_data = pd.read_csv('flight_price.csv')

# Check the dimensions of the dataset
print('Number of rows:', flight_data.shape[0])
print('Number of columns:', flight_data.shape[1])

Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.
Ans. import matplotlib.pyplot as plt

# Create a histogram of flight prices
plt.hist(flight_data['price'], bins=50)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Prices')
plt.show()

Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
Ans. # Find the minimum and maximum prices
min_price = flight_data['price'].min()
max_price = flight_data['price'].max()
price_range = max_price - min_price
print('Minimum price:', min_price)
print('Maximum price:', max_price)
print('Price range:', price_range)

Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.
Ans. # Create a boxplot of flight prices by airline
flight_data.boxplot(column='price', by='airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.title('Flight Prices by Airline')
plt.show()

Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.
Ans. # Create a boxplot of flight prices
flight_data.boxplot(column='price')
plt.ylabel('Price')
plt.title('Flight Prices')
plt.show()

Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price datasetto identify the peak
travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

Ans. To identify the peak travel season, you can analyze features such as the month of the flight, the destination, and the
average price over time. You could present your findings to your boss using a line graph showing the average flight price by month 
or a bar chart showing the number of flights by month.

Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify 
any trends in flight prices. What features would you analyze to identify thesetrends, and what visualizations would you use to present
your findings to your team?

Ans. To identify any trends in flight prices, you can analyze features such as the departure and arrival airports, the airline,
and the time of year. You could use visualizations such as line graphs or scatterplots to show how flight prices change over time 
or vary by different factors.

Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to
identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you
present your findings to the management team?

Ans. To identify the factors that affect flight prices, you can analyze features such as the departure and arrival airports, 
the airline, the time of year, the length of the flight, and the class of service. You could present your findings to the management 
team using a regression analysis to show how different variables impact flight prices, or using visualizations such as scatterplots
or heatmaps to highlight the relationships between variables.

Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns doesthe dataset have?
Ans. import pandas as pd

# Load the Google Playstore dataset
df = pd.read_csv('googleplaystore.csv')

# Print the dimensions of the dataset
print('Number of rows:', len(df))
print('Number of columns:', len(df.columns))

Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of differentapp categories.
Ans. import seaborn as sns

# Create a boxplot of app ratings by category
sns.boxplot(x='Category', y='Rating', data=df)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.show()

Q11. Are there any missing values in the dataset? Identify any missing values and describe how they mayimpact your analysis.
Ans. import pandas as pd

# Load the Google Playstore dataset
df = pd.read_csv('googleplaystore.csv')

# Check for missing values
print(df.isnull().sum())

Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualizethe relationship.
Ans. import matplotlib.pyplot as plt

# Create a scatter plot of app rating vs. size
plt.scatter(df['Size'], df['Rating'])

# Add axis labels and a title
plt.xlabel('App Size (MB)')
plt.ylabel('App Rating')
plt.title('App Rating vs. Size')

# Show the plot
plt.show()

Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.
Ans. import pandas as pd

# Load the Google Playstore dataset
df = pd.read_csv("googleplaystore.csv")

# Create a frequency table for the "Category" column
freq_table = df["Category"].value_counts()
print(freq_table)

Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the appswith the highest number of installs.
Ans. # Calculate the average number of installs for each category
avg_installs_by_category = df.groupby("Category")["Installs"].mean()

# Sort the categories in descending order based on the average number of installs
sorted_categories = avg_installs_by_category.sort_values(ascending=False)

print(sorted_categories)

Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze theGoogle Playstore dataset 
to identify the most popular app categories. How would you approach thistask, and what features would you analyze to make
recommendations to the company?

Ans. To identify the most popular app categories on the Google Playstore, I would analyze the number of downloads for each app category.
Here's how I would approach this task:

Extract the necessary data: I would extract the app category and number of downloads columns from the Google Playstore dataset.

Group the data by app category: I would group the data by app category to calculate the total number of downloads for each category.

Sort the data by number of downloads: I would sort the data in descending order by number of downloads to identify the most popular app categories.

Visualize the data: I would present the findings to the company using a bar chart or a pie chart to show the distribution of downloads across 
different app categories.

To make recommendations to the company, I would suggest focusing on the most popular app categories identified from the analysis. 
Additionally, I would recommend looking at the competition within those categories and analyzing the features and user feedback of 
the top apps in those categories to identify areas for improvement and differentiation.

Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify themost successfulapp developers.
What features would you analyze to make recommendations to thecompany, and what data visualizations would you use to present your findings?

Ans. To identify the most successful app developers, some features that can be analyzed include:

Number of apps developed by each developer
Average rating of apps developed by each developer
Total number of installs for all apps developed by each developer
Price range of apps developed by each developer
App categories developed by each developer
To present the findings, the company can use various data visualizations, such as:

Bar charts to compare the number of apps developed by each developer
Scatter plots to visualize the relationship between the average rating of apps and the total number of installs for each developer
Box plots to compare the price range of apps developed by each developer
Pie charts to visualize the distribution of app categories developed by each developer

Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time tolaunch a new app. What 
features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

Ans. To identify the best time to launch a new app, some features that can be analyzed include:

Number of installs over time for apps in the same category
Number of reviews over time for apps in the same category
Ratings over time for apps in the same category
Seasonality trends in app downloads and usage
To present the findings, the marketing research firm can use various data visualizations, such as:

Line charts to show the trend in number of installs, reviews, and ratings over time for apps in the same category
Bar charts to compare the number of installs, reviews, and ratings over time for apps in the same category
Heat maps to visualize the seasonality trends in app downloads and usage over time
Scatter plots to visualize the relationship between number of installs and time of year, and to identify any patterns or trends.
